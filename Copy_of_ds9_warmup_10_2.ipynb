# %% [markdown]
# <a href="https://colab.research.google.com/github/themidwestcanapps/Audio-Spectrum-Analyzer-in-Python/blob/master/Copy_of_ds9_warmup_10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Practice

# %%
# Read a csv file from a specified source and print the first 5 rows
import pandas as pd
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

print(diamonds.shape)
diamonds.head()
# Out:
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds['quality_color'] = diamonds['cut'].str.cat(diamonds['color'], sep="-")

diamonds.head()
# Out:
#    carat      cut color clarity  depth  ...  price     x     y     z  quality_color
# 0   0.23    Ideal     E     SI2   61.5  ...    326  3.95  3.98  2.43        Ideal-E
# 1   0.21  Premium     E     SI1   59.8  ...    326  3.89  3.84  2.31      Premium-E
# 2   0.23     Good     E     VS1   56.9  ...    327  4.05  4.07  2.31         Good-E
# 3   0.29  Premium     I     VS2   62.4  ...    334  4.20  4.23  2.63      Premium-I
# 4   0.31     Good     J     SI2   63.3  ...    335  4.34  4.35  2.75         Good-J
#
# [5 rows x 11 columns]

# %%
df_ko = diamonds.rename(columns={'table': 'shelf', 'carat':'doc'})

# %%
df_ko.drop('doc', axis=1, inplace=True)

# %%
df_ko.dtypes
# Out:
# cut               object
# color             object
# clarity           object
# depth            float64
# shelf            float64
# price              int64
# x                float64
# y                float64
# z                float64
# quality_color     object
# dtype: object

# %%
df_ko.head()
# Out:
#        cut color clarity  depth  shelf  price     x     y     z quality_color
# 0    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43       Ideal-E
# 1  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31     Premium-E
# 2     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31        Good-E
# 3  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63     Premium-I
# 4     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75        Good-J

# %%
diamonds.sort_values(['carat'], ascending=False)
# Out:
#        carat        cut color clarity  ...      x      y     z  quality_color
# 27415   5.01       Fair     J      I1  ...  10.74  10.54  6.98         Fair-J
# 27630   4.50       Fair     J      I1  ...  10.23  10.16  6.72         Fair-J
# 27130   4.13       Fair     H      I1  ...  10.00   9.85  6.43         Fair-H
# 25999   4.01    Premium     J      I1  ...  10.02   9.94  6.24      Premium-J
# 25998   4.01    Premium     I      I1  ...  10.14  10.10  6.17      Premium-I
# 26444   4.00  Very Good     I      I1  ...  10.01   9.94  6.31    Very Good-I
# 26534   3.67    Premium     I      I1  ...   9.86   9.81  6.13      Premium-I
# 23644   3.65       Fair     H      I1  ...   9.53   9.48  6.38         Fair-H
# 27679   3.51    Premium     J     VS2  ...   9.66   9.63  6.03      Premium-J
# 24328   3.50      Ideal     H      I1  ...   9.65   9.59  6.03        Ideal-H
# 26431   3.40       Fair     D      I1  ...   9.42   9.34  6.27         Fair-D
# ...

# %%
df_ko[(df_ko.x > 5) & (df_ko.y > 5) & (df_ko.z >5)]
# Out:
#              cut color clarity  depth  ...     x      y      z  quality_color
# 11778       Fair     J      I1   70.0  ...  7.34   7.28   5.12         Fair-J
# 13002       Fair     J      I1   69.4  ...  7.74   7.70   5.36         Fair-J
# 13118       Fair     J      I1   65.5  ...  8.01   7.95   5.23         Fair-J
# 13562       Fair     F      I1   66.6  ...  7.59   7.56   5.04         Fair-F
# 13757       Fair     J      I1   66.7  ...  8.04   8.02   5.36         Fair-J
# 13929       Fair     I      I1   66.0  ...  7.78   7.74   5.10         Fair-I
# 13991       Fair     I      I1   67.4  ...  7.71   7.64   5.17         Fair-I
# 14138       Fair     J      I1   67.6  ...  8.05   8.00   5.43         Fair-J
# 14504       Fair     J      I1   68.0  ...  7.43   7.39   5.04         Fair-J
# 14645       Fair     H      I1   69.8  ...  7.60   7.56   5.29         Fair-H
# 14881       Fair     H      I1   67.3  ...  7.50   7.47   5.04         Fair-H
# ...

# %%
df_ko['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df_fire = df_ko.apply(lambda row: row[~df_ko['cut'].isin(['Good', 'Very Good', 'Fair'])])

# %%
df_fire
# Out:
#            cut color clarity  depth  ...     x     y     z  quality_color
# 0        Ideal     E     SI2   61.5  ...  3.95  3.98  2.43        Ideal-E
# 1      Premium     E     SI1   59.8  ...  3.89  3.84  2.31      Premium-E
# 3      Premium     I     VS2   62.4  ...  4.20  4.23  2.63      Premium-I
# 11       Ideal     J     VS1   62.8  ...  3.93  3.90  2.46        Ideal-J
# 12     Premium     F     SI1   60.4  ...  3.88  3.84  2.33      Premium-F
# 13       Ideal     J     SI2   62.2  ...  4.35  4.37  2.71        Ideal-J
# 14     Premium     E     SI2   60.2  ...  3.79  3.75  2.27      Premium-E
# 15     Premium     E      I1   60.9  ...  4.38  4.42  2.68      Premium-E
# 16       Ideal     I     SI2   62.0  ...  4.31  4.34  2.68        Ideal-I
# 26     Premium     I     VS1   62.5  ...  3.97  3.94  2.47      Premium-I
# 39       Ideal     I     SI2   61.8  ...  4.49  4.51  2.78        Ideal-I
# 40       Ideal     I     SI2   61.2  ...  4.49  4.50  2.75        Ideal-I
# ...

# %%
#

# %%
df_ko.groupby(['cut']).price.sum().plot();

# %%
distro

# %%
# Apply a seaborn pairplot and explore relationships
# What does this visualization say about our features?
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
import seaborn as sns
sns.set(style='ticks', color_codes=True)
diamond = sns.load_dataset("diamonds")
sole = sns.pairplot(diamond)
